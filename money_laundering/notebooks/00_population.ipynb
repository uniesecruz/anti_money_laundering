# %%
# !kaggle datasets download -d ealtman2019/ibm-transactions-for-anti-money-laundering-aml --unzip -p ../data/external
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\win\Desktop\TCC\.venv\Scripts\kaggle.exe\__main__.py", line 7, in <module>
#     sys.exit(main())
#              ~~~~^^
#   File "C:\Users\win\Desktop\TCC\.venv\Lib\site-packages\kaggle\cli.py", line 68, in main
#     out = args.func(**command_args)
#   File "C:\Users\win\Desktop\TCC\.venv\Lib\site-packages\kaggle\api\kaggle_api_extended.py", line 1741, in dataset_download_cli
#     with self.build_kaggle_client() as kaggle:
#          ~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\win\Desktop\TCC\.venv\Lib\site-packages\kaggle\api\kaggle_api_extended.py", line 688, in build_kaggle_client
#     username=self.config_values['username'],
#              ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'username'

# %%
import os
import shutil

# Caminho atual do kaggle.json
src = '../references/kaggle.json'
# Caminho destino padrão do Kaggle
dst_dir = os.path.expanduser('~/.kaggle')
os.makedirs(dst_dir, exist_ok=True)
shutil.copy(src, os.path.join(dst_dir, 'kaggle.json'))
print('kaggle.json copiado para', dst_dir)
