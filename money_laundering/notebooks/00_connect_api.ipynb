# %%
import os
import shutil

# Caminho atual do kaggle.json
src = '../references/kaggle.json'
# Caminho destino padrão do Kaggle
dst_dir = os.path.expanduser('~/.kaggle')
os.makedirs(dst_dir, exist_ok=True)
shutil.copy(src, os.path.join(dst_dir, 'kaggle.json'))
print('kaggle.json copiado para', dst_dir)
# Out:
# kaggle.json copiado para C:\Users\win/.kaggle

# %%
# !kaggle datasets download -d ealtman2019/ibm-transactions-for-anti-money-laundering-aml --unzip -p ../data/external
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ealtman2019/ibm-transactions-for-anti-money-laundering-aml
# License(s): Community Data License Agreement - Sharing - Version 1.0
# ...
#   0%|          | 0.00/7.61G [00:00<?, ?B/s]
#   2%|▏         | 123M/7.61G [00:00<00:06, 1.29GB/s]
#   3%|▎         | 265M/7.61G [00:00<00:05, 1.40GB/s]
#   5%|▌         | 412M/7.61G [00:00<00:05, 1.47GB/s]
#   7%|▋         | 557M/7.61G [00:00<00:05, 1.48GB/s]
#   9%|▉         | 704M/7.61G [00:00<00:04, 1.50GB/s]
#  11%|█         | 848M/7.61G [00:00<00:04, 1.50GB/s]
#  13%|█▎        | 997M/7.61G [00:00<00:04, 1.52GB/s]
#  15%|█▍        | 1.12G/7.61G [00:01<00:13, 517MB/s]
#  17%|█▋        | 1.26G/7.61G [00:01<00:10, 651MB/s]
#  18%|█▊        | 1.39G/7.61G [00:01<00:08, 781MB/s]
#  20%|██        | 1.53G/7.61G [00:01<00:07, 912MB/s]
#  22%|██▏       | 1.67G/7.61G [00:01<00:06, 1.04GB/s]
#  24%|██▍       | 1.81G/7.61G [00:01<00:05, 1.14GB/s]
#  26%|██▌       | 1.95G/7.61G [00:02<00:04, 1.23GB/s]
# ...
